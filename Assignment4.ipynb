# %% [markdown]
# ---
# title: "Assignment4"
# author: "Taylor McKinley"
# date: "September 26, 2018"
# output: word_document
# ---
#
# #1
# ```{r}
# functionf = function(x)
# {
#   return(x^2+3*x+1)
# }
# functionf(3)
# ```
#
# #2
# ```{r}
# vec1 = c(1,2,4,12,3)
# prod(vec1, na.rm = FALSE)
# ```
#
# #3
# ```{r}
# vec2 = c(NA, 22, 4, 13, NA)
# vec2[is.na(vec2)]=3
# vec2
#
# ```
#
# #4
# ```{r}
# vec2 = c(NA, 22, 4, 13, NA)
# vec2[is.na(vec2)]=mean(vec2, na.rm = TRUE)
# vec2
# ```
#
# #5
# ```{r}
# x = matrix(c(1,1,0,2,NA,3,4,5,6,7,NA,9),ncol=3)
# for (i in 1:ncol(x))
# {
#  x[,i][is.na(x[,i])] = mean (x[,i], 0 + i, na.rm = TRUE)
#
# }
# x
# ```
#
#
# #6
# ```{r}
# library(ggplot2)
# vec3 = c(1,7,12,7,2)
# data <- data.frame(vec3)
# data$vec3 = factor(data$vec3)
# ggplot(data, aes(x = vec3)) + geom_bar()
#
# ```
#
# #7
# ```{r}
# vec3 = c(1,7,12,9,7)
# vec4 = c(2,4,15,7,15)
# data2 <- data.frame(vec3)
# data2 <- data.frame(vec3)
# data2 <- data.frame(cbind(vec3,vec4))
# data2$vec3 = factor(data2$vec3)
# data2$vec4 = factor(data2$vec4)
# ggplot(data2, aes(x = data2[,1], fill = data2[,2])) + geom_bar()
# ```
